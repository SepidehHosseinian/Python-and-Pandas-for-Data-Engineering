# %% [markdown]
# ### Selcting Dataframe Data

# %%
import pandas as pd
dta_path='../data/housing.csv'
df = pd.read_csv(dta_path)
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %% [markdown]
# ### Boolean Mask

# %%
mask=[False for _ in range(len (df))]
mask[3:7]= [True] *4
mask
# Out:
# [False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
df[mask]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY

# %%
df.loc[mask]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY

# %%
mask=df.loc[: ,'population'] < df.loc[:,'households']
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Length: 20640, dtype: bool

# %%
df.loc[mask]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5342     -118.44     34.04                16.0         18.0             6.0
# 11849    -121.00     39.75                 8.0       1116.0           214.0
# 19522    -121.00     37.65                17.0        484.0           202.0
#
#        population  households  median_income  median_house_value  \
# 5342          3.0         4.0         0.5360            350000.0
# 11849        27.0        39.0         2.5893             83000.0
# 19522       198.0       204.0         0.6825            187500.0
#
#       ocean_proximity
# 5342        <1H OCEAN
# 11849          INLAND
# 19522          INLAND

# %%
mask= df.loc[:,'median_income']>15
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: median_income, Length: 20640, dtype: bool

# %%
df.loc[mask]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1566     -121.96     37.74                 2.0        200.0            20.0
# 4352     -118.37     34.10                37.0        407.0            67.0
# 4604     -118.33     34.06                52.0       1841.0           240.0
# 4605     -118.33     34.07                52.0       2248.0           255.0
# 4606     -118.33     34.07                52.0       1482.0           171.0
# 4626     -118.32     34.06                52.0        955.0           100.0
# 4678     -118.34     34.08                52.0       1721.0           195.0
# 5242     -118.40     34.11                32.0       5578.0           753.0
# 5247     -118.44     34.09                36.0       3129.0           392.0
# 5248     -118.43     34.08                46.0        778.0            90.0
# 5257     -118.49     34.06                42.0       2861.0           360.0
# ...

# %% [markdown]
# ### Pandas Boolean Operators
# And :&
# Or :|
# Not: ~

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
mask= (df.loc[:,'median_income']>15) & (df.loc[:, 'median_house_value']>350000)
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Length: 20640, dtype: bool

# %%
df.loc[mask]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4352     -118.37     34.10                37.0        407.0            67.0
# 4604     -118.33     34.06                52.0       1841.0           240.0
# 4605     -118.33     34.07                52.0       2248.0           255.0
# 4606     -118.33     34.07                52.0       1482.0           171.0
# 4626     -118.32     34.06                52.0        955.0           100.0
# 4678     -118.34     34.08                52.0       1721.0           195.0
# 5242     -118.40     34.11                32.0       5578.0           753.0
# 5247     -118.44     34.09                36.0       3129.0           392.0
# 5248     -118.43     34.08                46.0        778.0            90.0
# 5257     -118.49     34.06                42.0       2861.0           360.0
# 5275     -118.50     34.05                36.0       4152.0           542.0
# ...

# %% [markdown]
# ### Creating New Column

# %%
df.loc[:,'rooms']= df.loc[:,'total_rooms']/df.loc[:, 'total_bedrooms']

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'reach_people', 'rooms'],
#       dtype='object')
